# %% [markdown]
# <a href="https://colab.research.google.com/github/9yifanchen9/MATH3881-5881/blob/week-3/tutorials/week03/Week3_Practice_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 Practice Tutorial: Feedforward Networks on MNIST
#
# **MATH3881 / MATH5881, UNSW.** Instructor: Sarat Moka.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saratmoka/MATH3881-5881/blob/main/tutorials/week03/Week3_Practice_Tutorial.ipynb)
#
# Today you will do two things.
#
# **Problem 1.** Train your first feedforward neural network on MNIST, step by step, in PyTorch. You will see loss curves, overfitting, and what each piece of the training loop is doing.
#
# **Problem 2.** Test the *dropout-as-ensemble* claim empirically. Train one network with dropout, then separately train a handful of small thinned subnetworks and average their predictions. You should find that the two strategies give comparable test accuracy, which is the heart of why dropout works.
#
# The notebook is designed for Google Colab (no local install required). A CPU runtime is enough; GPU just makes it faster. Estimated total running time on CPU: about 5 minutes.

# %% [markdown]
# ## Setup

# %% [markdown]
# We import PyTorch, torchvision (for MNIST), matplotlib, and numpy. We detect whether a GPU is available, and seed every random number generator the notebook touches so that re-running gives exactly the same numbers.
#
# There are five separate sources of randomness in a typical training run: Python's built-in `random`, NumPy's RNG, PyTorch's CPU RNG, PyTorch's CUDA RNG, and cuDNN's choice of which kernel to use. We pin all five below.

# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Seed every random number generator we touch, so the notebook is reproducible.
SEED = 0
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
# Make cuDNN pick deterministic algorithms (slight speed cost; matters only on GPU).
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Using device: cpu

# %% [markdown]
# ---
#
# ## Problem 1.  A feedforward network on MNIST, step by step

# %% [markdown]
# ### 1.1 Load the MNIST dataset
#
# MNIST is a collection of 70,000 hand-written digit images (60,000 train, 10,000 test), each $28 \times 28$ grayscale, with labels in $\{0, 1, \ldots, 9\}$. Our network takes a flat vector of length $784$, so we need to flatten each image and normalise pixel values to $[0, 1]$. PyTorch handles both through a *transform pipeline* that runs automatically every time a sample is loaded.

# %% [markdown]
# **Step 1: the transform pipeline.** A torchvision transform is a callable that maps one sample to another. We chain several together with `transforms.Compose([...])`, which applies each transform left-to-right (function composition: the output of one is the input of the next). For MNIST we need two steps.
#
# * `transforms.ToTensor()` converts a PIL image (8-bit integers $0, 1, \ldots, 255$) to a float tensor in $[0, 1]$ with shape `(1, 28, 28)`. The division by $255$ happens automatically; this is the normalisation step.
# * `transforms.Lambda(lambda x: x.view(-1))` reshapes that `(1, 28, 28)` tensor into a length-784 vector. This is the flatten step needed because our model is a feedforward (not convolutional) network.
#
# The composed `transform` is attached to the dataset object; each sample passes through it on the fly when loaded.

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                    # PIL image -> float tensor in [0, 1], shape (1, 28, 28)
    transforms.Lambda(lambda x: x.view(-1)),  # flatten to a length-784 vector
])

# %% [markdown]
# **Step 2: load the train and test datasets.** `torchvision.datasets.MNIST` provides the standard dataset. The arguments are:
#
# * `'./data'`: where to store the dataset files on disk. On the first run the files are downloaded; on subsequent runs they are read from cache.
# * `train=True / train=False`: MNIST ships with two fixed partitions, a 60,000-sample training set and a 10,000-sample test set. We load both. The split between them was set by the dataset providers; we do not get to choose it. The convention of separating train from test is universal in supervised learning: anything used during training cannot also be used to evaluate generalisation.
# * `download=True`: download if not present locally (a few megabytes; takes seconds on Colab).
# * `transform=transform`: apply the pipeline above to every sample.

# %%
train_full = datasets.MNIST('./data', train=True,  download=True, transform=transform)
test_set   = datasets.MNIST('./data', train=False, download=True, transform=transform)

print(f'Official train set: {len(train_full):,}    Official test set: {len(test_set):,}')
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.88MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 155kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.46MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.3MB/s]
# Official train set: 60,000    Official test set: 10,000

# %% [markdown]
# **Step 3: carve a small training set and a validation set out of the official training set.** During training we want to monitor whether the model is generalising, but we are *not* allowed to look at the test set. Any decision we make based on the test set (when to stop, which hyperparameter to pick, which architecture to use) leaks information from it into the model, and the final test accuracy is no longer an honest estimate of generalisation. The standard fix is to carve a *validation* set out of the official training data and keep the test set sealed until the very end.
#
# We use `torch.utils.data.random_split` to partition `train_full` into a 5,000-sample training set, a 10,000-sample validation set, and a 45,000-sample remainder that we discard. The split is deterministic given our seed.
#
# Why only 5,000 training samples when 60,000 are available? **Pedagogical choice.** With the full training set, MNIST is so easy that even a small feedforward network reaches $97\%+$ test accuracy without any regularisation, and we never get to see the regularisers earn their keep. Training on only 5,000 samples makes the network overfit visibly: train accuracy will climb near $100\%$ while test accuracy lags well behind, and that gap is what dropout (and friends) are there to close. In a real project you would use all the data you can get.

# %%
train_set, val_set, _discard = random_split(
    train_full,
    [5_000, 10_000, 45_000],
    generator=torch.Generator().manual_seed(SEED),
)

# %% [markdown]
# **Step 4: batching with `DataLoader`.** A `DataLoader` wraps a dataset and yields mini-batches. We use:
#
# * **Training**: batch size 128, `shuffle=True`. Shuffling each epoch decorrelates the gradient updates across passes and helps generalisation.
# * **Validation and test**: batch size 512, `shuffle=False`. Larger batches are faster (no backprop needed for evaluation) and shuffling has no effect on the result.

# %%
# Explicit generator on the train loader makes the per-epoch shuffle reproducible.
train_loader = DataLoader(train_set, batch_size=128, shuffle=True,
                          generator=torch.Generator().manual_seed(SEED))
val_loader   = DataLoader(val_set,   batch_size=512, shuffle=False)
test_loader  = DataLoader(test_set,  batch_size=512, shuffle=False)

print(f'Train: {len(train_set):,}    Val: {len(val_set):,}    Test: {len(test_set):,}')
# Out:
# Train: 5,000    Val: 10,000    Test: 10,000

# %% [markdown]
# A look at a few training digits with their labels.

# %%
fig, axes = plt.subplots(2, 8, figsize=(10, 3))
for ax, (x, y) in zip(axes.flat, train_set):
    ax.imshow(x.view(28, 28), cmap='gray')
    ax.set_title(f'{y}', fontsize=10)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Define the model
#
# Our architecture: a feedforward network with two hidden layers,
# $$ 784 \;\xrightarrow{\;W^{[1]}, b^{[1]}\;}\; 128 \;\xrightarrow{\mathrm{ReLU}}\; 128 \;\xrightarrow{\;W^{[2]}, b^{[2]}\;}\; 64 \;\xrightarrow{\mathrm{ReLU}}\; 64 \;\xrightarrow{\;W^{[3]}, b^{[3]}\;}\; 10. $$
# This is exactly the kind of network from Week 2, written in PyTorch building blocks. Each block is a Python object:
#
# * `nn.Linear(in_features, out_features)` is the affine map $x \mapsto Wx + b$. PyTorch creates the weight matrix $W$ (shape `(out_features, in_features)`) and bias vector $b$ as *trainable parameters* automatically; you do not initialise them by hand. The PyTorch default initialisation is close to the Xavier scheme from Week 2 §6.
# * `nn.ReLU()` applies $\max(0, \cdot)$ elementwise. It has no parameters; it is just a function masquerading as a module.
# * `nn.Sequential(layer_1, layer_2, \ldots)` is a container that chains its arguments. Calling `model(x)` runs $x$ through them left-to-right; calling `model.parameters()` returns all trainable parameters across the chain. This is what lets the optimiser update *every* weight matrix in one call.
#
# One subtlety: the final layer outputs raw scores (called *logits*), not probabilities. We do not append a softmax. The reason is numerical: `nn.CrossEntropyLoss` (Section 1.3) applies log-softmax internally with a numerically stable formula, and applying softmax twice would be wasteful and unstable.
#
# After defining the model we call `.to(device)`, which moves all parameter tensors to the GPU if one is available, or leaves them on CPU otherwise. Subsequent inputs `x` also need to be moved to the same device.

# %%
def make_model(hidden1=128, hidden2=64, dropout_p=0.0):
    layers = [
        nn.Linear(784, hidden1),
        nn.ReLU(),
    ]
    if dropout_p > 0:
        layers.append(nn.Dropout(dropout_p))
    layers += [
        nn.Linear(hidden1, hidden2),
        nn.ReLU(),
    ]
    if dropout_p > 0:
        layers.append(nn.Dropout(dropout_p))
    layers += [nn.Linear(hidden2, 10)]
    return nn.Sequential(*layers)

model = make_model().to(device)
n_params = sum(p.numel() for p in model.parameters())
print(model)
print(f'Trainable parameters: {n_params:,}')
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=10, bias=True)
# )
# Trainable parameters: 109,386

# %% [markdown]
# ### 1.3 Loss function and optimiser
#
# Two PyTorch objects do the heavy lifting during training.
#
# **`nn.CrossEntropyLoss`** is the softmax cross-entropy loss from Week 1. For a single sample with true class $y \in \{0, \ldots, 9\}$ and predicted logits $z \in \mathbb{R}^{10}$, it computes
# $$ \ell(z, y) \;=\; -\log \frac{e^{z_y}}{\sum_{k=0}^{9} e^{z_k}} \;=\; -z_y + \log \sum_k e^{z_k}, $$
# the negative log-probability that the network assigns to the correct class. It accepts logits (not probabilities) precisely so that the log-sum-exp on the right can be evaluated with the numerically stable trick (subtracting $\max_k z_k$ inside the exponentials).
#
# **`optim.SGD`** implements gradient descent. We pass it `model.parameters()` (every weight matrix and bias vector that needs updating) together with two knobs:
#
# * `lr=0.01` is the learning rate $\alpha$ from Week 3 §1, the step size in $\theta \leftarrow \theta - \alpha\, \nabla C(\theta)$.
# * `momentum=0.9` is a mild improvement on plain GD that we will study properly in Week 4. For now, think of it as smoothing the gradient direction across iterations.
#
# After this cell, the optimiser holds *references* to the model's parameters. Calling `optimizer.step()` updates them in place using whatever gradients are currently sitting on them.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### 1.4 Training and evaluation loops
#
# Training a network in PyTorch is the same five-line dance, repeated for every mini-batch:
#
# 1. `optimizer.zero_grad()` — set the gradient of every parameter to zero. By default PyTorch *accumulates* gradients into the `.grad` attribute of each parameter, so if you forget this step, you are effectively summing gradients across batches.
# 2. `logits = model(x)` — forward pass. This runs the input through every layer in `nn.Sequential`.
# 3. `loss = criterion(logits, y)` — evaluate the loss as a scalar tensor.
# 4. `loss.backward()` — backpropagation, computed automatically by PyTorch's autograd. We will not implement this by hand in this course, but conceptually it walks the computational graph backwards and fills in $\partial \text{loss} / \partial \theta$ for every learnable parameter $\theta$ (see Week 3, §3-4 for the underlying algorithm).
# 5. `optimizer.step()` — take one gradient descent step using those gradients.
#
# Two more details show up in the helpers below.
#
# * `model.train()` and `model.eval()` switch the model between training mode and evaluation mode. The behaviour of some layers (notably `nn.Dropout` and `nn.BatchNorm`) differs between the two: dropout zeros activations only in train mode; batch norm uses batch statistics in train mode and a running average in eval mode.
# * The `@torch.no_grad()` decorator on `evaluate` tells PyTorch not to build a computational graph for the forward pass, which saves memory and time. Use it whenever you only want predictions, not gradients.
#
# Both functions return the per-sample loss (so values from different batch sizes are comparable) and the classification accuracy.

# %%
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss, total_correct, total_count = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        total_loss    += loss.item() * x.size(0)
        total_correct += (logits.argmax(dim=1) == y).sum().item()
        total_count   += x.size(0)
    return total_loss / total_count, total_correct / total_count

@torch.no_grad()
def evaluate(model, loader, criterion):
    model.eval()
    total_loss, total_correct, total_count = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = criterion(logits, y)
        total_loss    += loss.item() * x.size(0)
        total_correct += (logits.argmax(dim=1) == y).sum().item()
        total_count   += x.size(0)
    return total_loss / total_count, total_correct / total_count

# %% [markdown]
# ### 1.5 Train the model
#
# We wrap everything in a `fit` function that loops over epochs. An *epoch* is one full pass through the training set: with 5,000 samples and batch size 128, the train loader yields $\lceil 5{,}000 / 128 \rceil = 40$ batches per epoch, and we run `train_one_epoch` on all of them. After each epoch we also evaluate on the validation set, so we can watch how the network is doing on data it has not seen during the gradient updates.
#
# We train for 60 epochs. With only 5,000 training samples, an unregularised feedforward network has enough capacity to essentially memorise the training set, and the training accuracy approaches $100\%$. The validation loss, however, plateaus partway through and then starts to creep upward; that movement, validation loss going up while training loss keeps going down, is the textbook signature of overfitting.

# %%
def fit(model, n_epochs=60, lr=0.01, momentum=0.9,
        train_loader=train_loader, val_loader=val_loader):
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
    for epoch in range(1, n_epochs + 1):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, optimizer, criterion)
        va_loss, va_acc = evaluate(model, val_loader, criterion)
        history['train_loss'].append(tr_loss); history['val_loss'].append(va_loss)
        history['train_acc'].append(tr_acc);   history['val_acc'].append(va_acc)
        print(f'epoch {epoch:2d}  train loss {tr_loss:.4f}  val loss {va_loss:.4f}  '
              f'train acc {tr_acc:.4f}  val acc {va_acc:.4f}')
    return history

torch.manual_seed(SEED)
model_baseline = make_model().to(device)
hist_baseline = fit(model_baseline, n_epochs=60)
# Out:
# epoch  1  train loss 2.2684  val loss 2.1986  train acc 0.1902  val acc 0.4517
# epoch  2  train loss 2.0151  val loss 1.6790  train acc 0.4640  val acc 0.5694
# epoch  3  train loss 1.2619  val loss 0.8815  train acc 0.6866  val acc 0.7577
# epoch  4  train loss 0.7105  val loss 0.6106  train acc 0.7992  val acc 0.8269
# epoch  5  train loss 0.5396  val loss 0.5126  train acc 0.8444  val acc 0.8527
# epoch  6  train loss 0.4544  val loss 0.4536  train acc 0.8738  val acc 0.8701
# epoch  7  train loss 0.3988  val loss 0.4126  train acc 0.8854  val acc 0.8838
# epoch  8  train loss 0.3567  val loss 0.4086  train acc 0.9008  val acc 0.8815
# epoch  9  train loss 0.3345  val loss 0.3773  train acc 0.9058  val acc 0.8918
# epoch 10  train loss 0.3178  val loss 0.3729  train acc 0.9118  val acc 0.8922
# epoch 11  train loss 0.3028  val loss 0.3538  train acc 0.9156  val acc 0.8969
# epoch 12  train loss 0.2814  val loss 0.3452  train acc 0.9194  val acc 0.9020
# epoch 13  train loss 0.2659  val loss 0.3719  train acc 0.9258  val acc 0.8912
# epoch 14  train loss 0.2855  val loss 0.3397  train acc 0.9156  val acc 0.9002
# epoch 15  train loss 0.2443  val loss 0.3336  train acc 0.9342  val acc 0.9041
# epoch 16  train loss 0.2346  val loss 0.3261  train acc 0.9346  val acc 0.9070
# epoch 17  train loss 0.2213  val loss 0.3510  train acc 0.9384  val acc 0.8982
# epoch 18  train loss 0.2450  val loss 0.3127  train acc 0.9270  val acc 0.9093
# epoch 19  train loss 0.2056  val loss 0.3084  train acc 0.9430  val acc 0.9116
# epoch 20  train loss 0.1917  val loss 0.2974  train acc 0.9476  val acc 0.9138
# epoch 21  train loss 0.1846  val loss 0.2978  train acc 0.9484  val acc 0.9136
# epoch 22  train loss 0.1765  val loss 0.3066  train acc 0.9516  val acc 0.9119
# epoch 23  train loss 0.1664  val loss 0.2982  train acc 0.9574  val acc 0.9154
# epoch 24  train loss 0.1619  val loss 0.2950  train acc 0.9552  val acc 0.9170
# epoch 25  train loss 0.1557  val loss 0.2991  train acc 0.9586  val acc 0.9134
# epoch 26  train loss 0.1540  val loss 0.2918  train acc 0.9558  val acc 0.9176
# epoch 27  train loss 0.1468  val loss 0.2845  train acc 0.9590  val acc 0.9185
# epoch 28  train loss 0.1476  val loss 0.3165  train acc 0.9560  val acc 0.9109
# epoch 29  train loss 0.1317  val loss 0.2772  train acc 0.9644  val acc 0.9215
# epoch 30  train loss 0.1248  val loss 0.2847  train acc 0.9672  val acc 0.9209
# epoch 31  train loss 0.1182  val loss 0.2818  train acc 0.9692  val acc 0.9207
# epoch 32  train loss 0.1111  val loss 0.2820  train acc 0.9700  val acc 0.9197
# epoch 33  train loss 0.1099  val loss 0.2810  train acc 0.9712  val acc 0.9208
# epoch 34  train loss 0.1004  val loss 0.2781  train acc 0.9758  val acc 0.9228
# epoch 35  train loss 0.0975  val loss 0.2709  train acc 0.9766  val acc 0.9243
# epoch 36  train loss 0.0917  val loss 0.2741  train acc 0.9786  val acc 0.9255
# epoch 37  train loss 0.0862  val loss 0.2733  train acc 0.9794  val acc 0.9254
# epoch 38  train loss 0.0844  val loss 0.2792  train acc 0.9814  val acc 0.9220
# epoch 39  train loss 0.0897  val loss 0.2707  train acc 0.9752  val acc 0.9253
# epoch 40  train loss 0.0844  val loss 0.2744  train acc 0.9780  val acc 0.9264
# epoch 41  train loss 0.0735  val loss 0.2813  train acc 0.9834  val acc 0.9223
# epoch 42  train loss 0.0849  val loss 0.2759  train acc 0.9770  val acc 0.9251
# epoch 43  train loss 0.0698  val loss 0.2697  train acc 0.9828  val acc 0.9300
# epoch 44  train loss 0.0617  val loss 0.2689  train acc 0.9866  val acc 0.9292
# epoch 45  train loss 0.0578  val loss 0.2720  train acc 0.9882  val acc 0.9283
# epoch 46  train loss 0.0550  val loss 0.2689  train acc 0.9884  val acc 0.9284
# epoch 47  train loss 0.0545  val loss 0.2715  train acc 0.9886  val acc 0.9277
# epoch 48  train loss 0.0490  val loss 0.2806  train acc 0.9916  val acc 0.9269
# epoch 49  train loss 0.0462  val loss 0.2699  train acc 0.9920  val acc 0.9304
# epoch 50  train loss 0.0437  val loss 0.2719  train acc 0.9922  val acc 0.9292
# epoch 51  train loss 0.0397  val loss 0.2708  train acc 0.9948  val acc 0.9306
# epoch 52  train loss 0.0398  val loss 0.2705  train acc 0.9940  val acc 0.9309
# epoch 53  train loss 0.0415  val loss 0.2782  train acc 0.9916  val acc 0.9281
# epoch 54  train loss 0.0363  val loss 0.2817  train acc 0.9942  val acc 0.9278
# epoch 55  train loss 0.0342  val loss 0.2836  train acc 0.9946  val acc 0.9282
# epoch 56  train loss 0.0323  val loss 0.2813  train acc 0.9956  val acc 0.9283
# epoch 57  train loss 0.0293  val loss 0.2769  train acc 0.9966  val acc 0.9306
# epoch 58  train loss 0.0276  val loss 0.2823  train acc 0.9972  val acc 0.9309
# epoch 59  train loss 0.0261  val loss 0.2816  train acc 0.9970  val acc 0.9311
# epoch 60  train loss 0.0238  val loss 0.2805  train acc 0.9980  val acc 0.9312

# %% [markdown]
# ### 1.6 Plot the training curves

# %%
def plot_history(histories, names, title=''):
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(11, 4))
    for h, name in zip(histories, names):
        epochs = range(1, len(h['train_loss']) + 1)
        ax_loss.plot(epochs, h['train_loss'], label=f'{name} train', linestyle='--')
        ax_loss.plot(epochs, h['val_loss'],   label=f'{name} val')
        ax_acc.plot(epochs, h['train_acc'],   label=f'{name} train', linestyle='--')
        ax_acc.plot(epochs, h['val_acc'],     label=f'{name} val')
    ax_loss.set_xlabel('epoch'); ax_loss.set_ylabel('loss'); ax_loss.legend(fontsize=8)
    ax_acc.set_xlabel('epoch'); ax_acc.set_ylabel('accuracy'); ax_acc.legend(fontsize=8)
    if title:
        fig.suptitle(title); fig.tight_layout()
    plt.show()

plot_history([hist_baseline], ['baseline'], title='Baseline FFN on MNIST')

# %% [markdown]
# ### 1.7 Final test accuracy
#
# Now, and only now, we touch the test set. It was sealed during training (we never used it to choose anything: not the architecture, not the learning rate, not the number of epochs). Its accuracy is our honest estimate of how well the model would do on completely new digits.
#
# We will also print the train accuracy at the last epoch and the *generalisation gap* (train minus test). A large positive gap means the model has fit the training data better than the test data, that is, it has memorised some patterns specific to the training set that do not transfer.

# %%
test_loss_baseline, test_acc_baseline = evaluate(model_baseline, test_loader, criterion)
print(f'Baseline test accuracy: {test_acc_baseline:.4f}  (test loss {test_loss_baseline:.4f})')
print(f'Train accuracy at last epoch: {hist_baseline["train_acc"][-1]:.4f}')
print(f'Generalisation gap (train acc minus test acc): '
      f'{hist_baseline["train_acc"][-1] - test_acc_baseline:+.4f}')
# Out:
# Baseline test accuracy: 0.9328  (test loss 0.2578)
# Train accuracy at last epoch: 0.9980
# Generalisation gap (train acc minus test acc): +0.0652

# %% [markdown]
# The gap between train and test accuracy is the network *over-fitting* the training data. Problem 2 attacks it from the dropout side. First, three small experiments.

# %% [markdown]
# > ### <font color="#1b5e20">1.8 Tasks</font>
# >
# > Two small experiments. Run them, look at the numbers, then think about what you observed.
# >
# > <font color="#1b5e20">**Task 1.8.1: change the seed.**</font> Pick another value for `SEED` (try 1, 42, 123) and re-run sections 1.5 through 1.7. How much does the final test accuracy move from run to run? If the seed-to-seed spread is comparable to the dropout-vs-baseline gap, you cannot conclude that dropout helps from a single comparison; you would need to average over seeds.
# >
# > <font color="#1b5e20">**Task 1.8.2: train on Fashion-MNIST.**</font> Fashion-MNIST is a drop-in replacement for MNIST with the same $28 \times 28$ grayscale shape and the same 10 classes, but the labels are clothing items (t-shirt, trouser, pullover, dress, coat, sandal, shirt, sneaker, bag, ankle boot) instead of digits. It is significantly harder than MNIST: the same architecture and recipe typically lands around 80% test accuracy instead of 93%+. In the code cell below, load Fashion-MNIST using `datasets.FashionMNIST` (same constructor signature as `datasets.MNIST`), build a 5,000 / 10,000 train/val split and corresponding DataLoaders, then re-train the baseline model and report the test accuracy alongside the MNIST baseline number. The point is to see that the same pipeline behaves very differently when the data is harder.

# %%
# Task 1.8.2: train the baseline model on Fashion-MNIST.
#
# Steps to fill in:
#   1. Load datasets.FashionMNIST for train and test, using the same `transform`
#      and the same './data' directory as in section 1.1.
fashion_train_full = datasets.FashionMNIST('./data', train=True,  download=True, transform=transform)
fashion_test_set   = datasets.FashionMNIST('./data', train=False, download=True, transform=transform)

#   2. Carve a [5_000, 10_000, 45_000] train / val / discard split with
#      random_split, seeded with torch.Generator().manual_seed(SEED).
fashion_train_set, fashion_val_set, _discard = random_split(
    fashion_train_full,
    [5_000, 10_000, 45_000],
    generator=torch.Generator().manual_seed(SEED),
)

#   3. Build new fmnist_train_loader, fmnist_val_loader, fmnist_test_loader
#      with the same batch sizes and seeded shuffling as in section 1.1.
fashion_train_loader = DataLoader(fashion_train_set, batch_size=128, shuffle=True,
                          generator=torch.Generator().manual_seed(SEED))
fashion_val_loader   = DataLoader(fashion_val_set,   batch_size=512, shuffle=False)
fashion_test_loader  = DataLoader(fashion_test_set,  batch_size=512, shuffle=False)

#   4. Re-seed (torch.manual_seed(SEED)) and create a fresh baseline
#      via make_model().to(device).
torch.manual_seed(SEED)
fashion_model_baseline = make_model().to(device)

#   5. Train for 60 epochs using fit(..., train_loader=..., val_loader=...).
fashion_hist_baseline = fit(fashion_model_baseline, n_epochs=60)

# %%
#   6. Evaluate on the Fashion-MNIST test loader and print the result
#      next to test_acc_baseline (the MNIST baseline accuracy).
plot_history([fashion_hist_baseline], ['baseline'], title='Baseline FFN on Fashion MNIST')
fashion_test_loss_baseline, fashion_test_acc_baseline = evaluate(fashion_model_baseline, fashion_test_loader, criterion)

# %% [markdown]
# ---
#
# ## Problem 2.  Dropout as an ensemble of thinned networks
#
# Recall (Week 2, §6) that dropout with keep-probability $p$ randomly zeros each hidden unit's activation, independently, each forward pass. The standard story is:
#
# > *Training one network of width $W$ with dropout is approximately equivalent to training an ensemble of $2^W$ thinned subnetworks (each picking a random subset of units) that share parameters; at test time, dropout's prediction is approximately the average of all thinned subnetworks' predictions.*
#
# We cannot afford to enumerate $2^W$ subnetworks. But we can sample $K$ of them, train each one separately on the same data, average their softmax outputs at test time, and compare to a single dropout-trained network. The claim is that the two should land in the same ballpark.
#
# We will compare three things:
#
# 1. **Baseline** (no regularisation) from Problem 1.
# 2. **One dropout net**: one network of width 128 trained with $\mathrm{Dropout}(0.5)$.
# 3. **Ensemble of $K$ thinned nets**: $K$ independent networks of half the width (64 hidden units each), no dropout, trained on the same data. At test time, we average their softmax probabilities.

# %% [markdown]
# ### 2.1 Train one network with dropout
#
# **What `nn.Dropout(p)` actually does.** During *training*, every time a tensor passes through this layer, each entry is independently set to zero with probability $p$ (the *drop* probability) and kept with probability $1-p$. The surviving entries are multiplied by $1/(1-p)$ so that the expected sum of activations is unchanged: this is the *inverted dropout* trick from Week 2 §6. During *evaluation* (`model.eval()`), dropout is the identity, no zeros, no scaling. This is why `model.train()` and `model.eval()` matter.
#
# We add a dropout layer after each ReLU, with keep-probability $1-p = 0.5$.

# %%
torch.manual_seed(SEED)
model_dropout = make_model(hidden1=128, hidden2=64, dropout_p=0.5).to(device)
hist_dropout  = fit(model_dropout, n_epochs=60)
test_loss_dropout, test_acc_dropout = evaluate(model_dropout, test_loader, criterion)
print(f'Dropout test accuracy: {test_acc_dropout:.4f}')
# Out:
# epoch  1  train loss 2.2806  val loss 2.2209  train acc 0.1394  val acc 0.4180
# epoch  2  train loss 2.1267  val loss 1.8849  train acc 0.3350  val acc 0.5264
# epoch  3  train loss 1.7053  val loss 1.2228  train acc 0.4660  val acc 0.6969
# epoch  4  train loss 1.2798  val loss 0.8682  train acc 0.5654  val acc 0.7670
# epoch  5  train loss 1.0343  val loss 0.7083  train acc 0.6544  val acc 0.7953
# epoch  6  train loss 0.9089  val loss 0.6097  train acc 0.7040  val acc 0.8302
# epoch  7  train loss 0.8019  val loss 0.5423  train acc 0.7494  val acc 0.8539
# epoch  8  train loss 0.7306  val loss 0.4994  train acc 0.7678  val acc 0.8604
# epoch  9  train loss 0.6751  val loss 0.4611  train acc 0.7966  val acc 0.8735
# epoch 10  train loss 0.6396  val loss 0.4390  train acc 0.8032  val acc 0.8750
# epoch 11  train loss 0.6126  val loss 0.4118  train acc 0.8162  val acc 0.8848
# epoch 12  train loss 0.5636  val loss 0.3923  train acc 0.8290  val acc 0.8902
# epoch 13  train loss 0.5320  val loss 0.3757  train acc 0.8374  val acc 0.8932
# epoch 14  train loss 0.5107  val loss 0.3605  train acc 0.8470  val acc 0.8965
# epoch 15  train loss 0.4911  val loss 0.3568  train acc 0.8506  val acc 0.8964
# epoch 16  train loss 0.4625  val loss 0.3478  train acc 0.8630  val acc 0.8999
# epoch 17  train loss 0.4834  val loss 0.3413  train acc 0.8584  val acc 0.9000
# epoch 18  train loss 0.4403  val loss 0.3331  train acc 0.8686  val acc 0.9057
# epoch 19  train loss 0.4498  val loss 0.3250  train acc 0.8750  val acc 0.9048
# epoch 20  train loss 0.4170  val loss 0.3111  train acc 0.8790  val acc 0.9084
# epoch 21  train loss 0.4065  val loss 0.3059  train acc 0.8808  val acc 0.9113
# epoch 22  train loss 0.3911  val loss 0.2981  train acc 0.8802  val acc 0.9120
# epoch 23  train loss 0.3698  val loss 0.2973  train acc 0.8952  val acc 0.9121
# epoch 24  train loss 0.3722  val loss 0.2976  train acc 0.8830  val acc 0.9111
# epoch 25  train loss 0.3467  val loss 0.2899  train acc 0.9016  val acc 0.9136
# epoch 26  train loss 0.3510  val loss 0.2862  train acc 0.8958  val acc 0.9134
# epoch 27  train loss 0.3525  val loss 0.2787  train acc 0.9000  val acc 0.9168
# epoch 28  train loss 0.3324  val loss 0.2854  train acc 0.9070  val acc 0.9175
# epoch 29  train loss 0.3193  val loss 0.2773  train acc 0.9108  val acc 0.9184
# epoch 30  train loss 0.3302  val loss 0.2731  train acc 0.9016  val acc 0.9199
# epoch 31  train loss 0.3039  val loss 0.2707  train acc 0.9114  val acc 0.9205
# epoch 32  train loss 0.3063  val loss 0.2675  train acc 0.9086  val acc 0.9216
# epoch 33  train loss 0.3092  val loss 0.2667  train acc 0.9114  val acc 0.9228
# epoch 34  train loss 0.2955  val loss 0.2649  train acc 0.9108  val acc 0.9227
# epoch 35  train loss 0.2850  val loss 0.2639  train acc 0.9154  val acc 0.9225
# epoch 36  train loss 0.3006  val loss 0.2617  train acc 0.9118  val acc 0.9216
# epoch 37  train loss 0.2745  val loss 0.2550  train acc 0.9188  val acc 0.9259
# epoch 38  train loss 0.2562  val loss 0.2552  train acc 0.9240  val acc 0.9239
# epoch 39  train loss 0.2653  val loss 0.2501  train acc 0.9200  val acc 0.9254
# epoch 40  train loss 0.2560  val loss 0.2531  train acc 0.9224  val acc 0.9261
# epoch 41  train loss 0.2533  val loss 0.2540  train acc 0.9234  val acc 0.9268
# epoch 42  train loss 0.2634  val loss 0.2551  train acc 0.9242  val acc 0.9266
# epoch 43  train loss 0.2390  val loss 0.2504  train acc 0.9266  val acc 0.9275
# epoch 44  train loss 0.2357  val loss 0.2493  train acc 0.9350  val acc 0.9265
# epoch 45  train loss 0.2263  val loss 0.2465  train acc 0.9344  val acc 0.9303
# epoch 46  train loss 0.2308  val loss 0.2466  train acc 0.9308  val acc 0.9281
# epoch 47  train loss 0.2229  val loss 0.2464  train acc 0.9352  val acc 0.9303
# epoch 48  train loss 0.2415  val loss 0.2486  train acc 0.9268  val acc 0.9296
# epoch 49  train loss 0.2157  val loss 0.2431  train acc 0.9352  val acc 0.9287
# epoch 50  train loss 0.2108  val loss 0.2440  train acc 0.9350  val acc 0.9314
# epoch 51  train loss 0.2047  val loss 0.2421  train acc 0.9452  val acc 0.9319
# epoch 52  train loss 0.2321  val loss 0.2417  train acc 0.9332  val acc 0.9295
# epoch 53  train loss 0.2155  val loss 0.2372  train acc 0.9356  val acc 0.9327
# epoch 54  train loss 0.2189  val loss 0.2367  train acc 0.9374  val acc 0.9336
# epoch 55  train loss 0.2057  val loss 0.2347  train acc 0.9408  val acc 0.9323
# epoch 56  train loss 0.1970  val loss 0.2349  train acc 0.9428  val acc 0.9336
# epoch 57  train loss 0.1991  val loss 0.2360  train acc 0.9412  val acc 0.9328
# epoch 58  train loss 0.1793  val loss 0.2407  train acc 0.9484  val acc 0.9326
# epoch 59  train loss 0.1847  val loss 0.2408  train acc 0.9448  val acc 0.9324
# epoch 60  train loss 0.1794  val loss 0.2441  train acc 0.9478  val acc 0.9328
# Dropout test accuracy: 0.9360

# %% [markdown]
# ### 2.2 Train $K$ thinned subnetworks
#
# Each thinned network has half the hidden width of the dropout net (a rough match: dropout with $p=0.5$ keeps half the units in expectation). We train $K = 5$ of them, each with a different random initialisation. There is no dropout in the thinned nets.

# %%
K = 5
thinned_models = []
for k in range(K):
    torch.manual_seed(SEED + 1 + k)  # different init each
    m = make_model(hidden1=64, hidden2=32, dropout_p=0.0).to(device)
    print(f'--- Thinned net {k + 1} of {K} ---')
    fit(m, n_epochs=60)
    thinned_models.append(m)

print(f'Trained {len(thinned_models)} thinned subnetworks.')
# Out:
# --- Thinned net 1 of 5 ---
# epoch  1  train loss 2.2909  val loss 2.2511  train acc 0.1062  val acc 0.1922
# epoch  2  train loss 2.1444  val loss 1.9207  train acc 0.4174  val acc 0.5754
# epoch  3  train loss 1.5401  val loss 1.1049  train acc 0.6296  val acc 0.6689
# epoch  4  train loss 0.8744  val loss 0.7094  train acc 0.7452  val acc 0.7814
# epoch  5  train loss 0.6075  val loss 0.5656  train acc 0.8158  val acc 0.8282
# epoch  6  train loss 0.5042  val loss 0.4956  train acc 0.8506  val acc 0.8527
# epoch  7  train loss 0.4349  val loss 0.4460  train acc 0.8794  val acc 0.8698
# epoch  8  train loss 0.3948  val loss 0.4171  train acc 0.8894  val acc 0.8814
# epoch  9  train loss 0.3625  val loss 0.3904  train acc 0.8982  val acc 0.8891
# epoch 10  train loss 0.3562  val loss 0.3943  train acc 0.9006  val acc 0.8872
# epoch 11  train loss 0.3251  val loss 0.3709  train acc 0.9106  val acc 0.8925
# epoch 12  train loss 0.3058  val loss 0.3649  train acc 0.9142  val acc 0.8939
# epoch 13  train loss 0.2920  val loss 0.3643  train acc 0.9194  val acc 0.8940
# epoch 14  train loss 0.2778  val loss 0.3768  train acc 0.9198  val acc 0.8855
# epoch 15  train loss 0.2707  val loss 0.3547  train acc 0.9226  val acc 0.8971
# epoch 16  train loss 0.2666  val loss 0.3344  train acc 0.9228  val acc 0.9038
# epoch 17  train loss 0.2434  val loss 0.3455  train acc 0.9326  val acc 0.8977
# epoch 18  train loss 0.2428  val loss 0.3307  train acc 0.9320  val acc 0.9020
# epoch 19  train loss 0.2267  val loss 0.3436  train acc 0.9366  val acc 0.8995
# epoch 20  train loss 0.2116  val loss 0.3105  train acc 0.9410  val acc 0.9124
# epoch 21  train loss 0.2045  val loss 0.3309  train acc 0.9410  val acc 0.9033
# epoch 22  train loss 0.1952  val loss 0.3102  train acc 0.9472  val acc 0.9102
# epoch 23  train loss 0.1815  val loss 0.3165  train acc 0.9484  val acc 0.9098
# epoch 24  train loss 0.1812  val loss 0.3035  train acc 0.9480  val acc 0.9104
# epoch 25  train loss 0.1668  val loss 0.3044  train acc 0.9514  val acc 0.9106
# epoch 26  train loss 0.1829  val loss 0.3001  train acc 0.9526  val acc 0.9150
# epoch 27  train loss 0.1551  val loss 0.2930  train acc 0.9572  val acc 0.9156
# epoch 28  train loss 0.1540  val loss 0.2941  train acc 0.9578  val acc 0.9144
# epoch 29  train loss 0.1487  val loss 0.2919  train acc 0.9586  val acc 0.9163
# epoch 30  train loss 0.1343  val loss 0.2909  train acc 0.9632  val acc 0.9185
# epoch 31  train loss 0.1280  val loss 0.2933  train acc 0.9664  val acc 0.9168
# epoch 32  train loss 0.1283  val loss 0.2919  train acc 0.9672  val acc 0.9179
# epoch 33  train loss 0.1235  val loss 0.2966  train acc 0.9662  val acc 0.9175
# epoch 34  train loss 0.1130  val loss 0.2877  train acc 0.9712  val acc 0.9177
# epoch 35  train loss 0.1084  val loss 0.2878  train acc 0.9718  val acc 0.9179
# epoch 36  train loss 0.1129  val loss 0.2999  train acc 0.9718  val acc 0.9157
# epoch 37  train loss 0.1024  val loss 0.2893  train acc 0.9734  val acc 0.9193
# epoch 38  train loss 0.1057  val loss 0.2896  train acc 0.9722  val acc 0.9197
# epoch 39  train loss 0.0915  val loss 0.2860  train acc 0.9782  val acc 0.9212
# epoch 40  train loss 0.0843  val loss 0.2890  train acc 0.9812  val acc 0.9214
# epoch 41  train loss 0.0846  val loss 0.3131  train acc 0.9788  val acc 0.9122
# epoch 42  train loss 0.0994  val loss 0.2878  train acc 0.9718  val acc 0.9211
# epoch 43  train loss 0.0767  val loss 0.2866  train acc 0.9810  val acc 0.9219
# epoch 44  train loss 0.0716  val loss 0.2881  train acc 0.9838  val acc 0.9218
# epoch 45  train loss 0.0657  val loss 0.2939  train acc 0.9842  val acc 0.9189
# epoch 46  train loss 0.0691  val loss 0.2922  train acc 0.9838  val acc 0.9185
# epoch 47  train loss 0.0602  val loss 0.2859  train acc 0.9862  val acc 0.9236
# epoch 48  train loss 0.0550  val loss 0.2918  train acc 0.9892  val acc 0.9222
# epoch 49  train loss 0.0528  val loss 0.2897  train acc 0.9890  val acc 0.9227
# epoch 50  train loss 0.0491  val loss 0.2893  train acc 0.9906  val acc 0.9241
# epoch 51  train loss 0.0467  val loss 0.2909  train acc 0.9930  val acc 0.9249
# epoch 52  train loss 0.0456  val loss 0.2939  train acc 0.9910  val acc 0.9225
# epoch 53  train loss 0.0431  val loss 0.2981  train acc 0.9930  val acc 0.9237
# epoch 54  train loss 0.0417  val loss 0.3009  train acc 0.9928  val acc 0.9214
# epoch 55  train loss 0.0395  val loss 0.2952  train acc 0.9942  val acc 0.9251
# epoch 56  train loss 0.0374  val loss 0.2946  train acc 0.9942  val acc 0.9237
# epoch 57  train loss 0.0342  val loss 0.3070  train acc 0.9950  val acc 0.9212
# epoch 58  train loss 0.0332  val loss 0.3072  train acc 0.9954  val acc 0.9240
# epoch 59  train loss 0.0319  val loss 0.3072  train acc 0.9960  val acc 0.9229
# epoch 60  train loss 0.0289  val loss 0.3109  train acc 0.9968  val acc 0.9229
# --- Thinned net 2 of 5 ---
# epoch  1  train loss 2.2687  val loss 2.1929  train acc 0.1582  val acc 0.3446
# epoch  2  train loss 1.9749  val loss 1.5639  train acc 0.5800  val acc 0.7137
# epoch  3  train loss 1.0847  val loss 0.7621  train acc 0.7546  val acc 0.7786
# epoch  4  train loss 0.6333  val loss 0.5654  train acc 0.8188  val acc 0.8272
# epoch  5  train loss 0.5103  val loss 0.4945  train acc 0.8526  val acc 0.8553
# epoch  6  train loss 0.4289  val loss 0.4500  train acc 0.8728  val acc 0.8655
# epoch  7  train loss 0.3825  val loss 0.4302  train acc 0.8922  val acc 0.8743
# epoch  8  train loss 0.3682  val loss 0.4012  train acc 0.8948  val acc 0.8803
# epoch  9  train loss 0.3287  val loss 0.3857  train acc 0.9082  val acc 0.8860
# epoch 10  train loss 0.3316  val loss 0.3701  train acc 0.9018  val acc 0.8935
# epoch 11  train loss 0.2934  val loss 0.3675  train acc 0.9158  val acc 0.8911
# epoch 12  train loss 0.2794  val loss 0.3598  train acc 0.9220  val acc 0.8978
# epoch 13  train loss 0.2689  val loss 0.3486  train acc 0.9218  val acc 0.8963
# epoch 14  train loss 0.2513  val loss 0.3402  train acc 0.9322  val acc 0.9006
# epoch 15  train loss 0.2488  val loss 0.3384  train acc 0.9292  val acc 0.9015
# epoch 16  train loss 0.2340  val loss 0.3256  train acc 0.9342  val acc 0.9063
# epoch 17  train loss 0.2205  val loss 0.3186  train acc 0.9392  val acc 0.9069
# epoch 18  train loss 0.2107  val loss 0.3136  train acc 0.9406  val acc 0.9084
# epoch 19  train loss 0.2098  val loss 0.3115  train acc 0.9412  val acc 0.9108
# epoch 20  train loss 0.1935  val loss 0.3010  train acc 0.9454  val acc 0.9119
# epoch 21  train loss 0.1896  val loss 0.3031  train acc 0.9462  val acc 0.9121
# epoch 22  train loss 0.1735  val loss 0.3039  train acc 0.9494  val acc 0.9096
# epoch 23  train loss 0.1715  val loss 0.3026  train acc 0.9486  val acc 0.9123
# epoch 24  train loss 0.1582  val loss 0.2942  train acc 0.9558  val acc 0.9153
# epoch 25  train loss 0.1685  val loss 0.2901  train acc 0.9508  val acc 0.9152
# epoch 26  train loss 0.1477  val loss 0.3038  train acc 0.9592  val acc 0.9118
# epoch 27  train loss 0.1750  val loss 0.2856  train acc 0.9490  val acc 0.9163
# epoch 28  train loss 0.1407  val loss 0.2787  train acc 0.9622  val acc 0.9199
# epoch 29  train loss 0.1260  val loss 0.2793  train acc 0.9678  val acc 0.9195
# epoch 30  train loss 0.1242  val loss 0.2798  train acc 0.9678  val acc 0.9218
# epoch 31  train loss 0.1141  val loss 0.2779  train acc 0.9718  val acc 0.9193
# epoch 32  train loss 0.1081  val loss 0.2802  train acc 0.9734  val acc 0.9194
# epoch 33  train loss 0.1036  val loss 0.2741  train acc 0.9752  val acc 0.9205
# epoch 34  train loss 0.1009  val loss 0.2950  train acc 0.9764  val acc 0.9178
# epoch 35  train loss 0.0983  val loss 0.2861  train acc 0.9752  val acc 0.9206
# epoch 36  train loss 0.0915  val loss 0.2744  train acc 0.9786  val acc 0.9223
# epoch 37  train loss 0.0838  val loss 0.2786  train acc 0.9810  val acc 0.9207
# epoch 38  train loss 0.0807  val loss 0.2782  train acc 0.9810  val acc 0.9226
# epoch 39  train loss 0.0798  val loss 0.2713  train acc 0.9814  val acc 0.9253
# epoch 40  train loss 0.0761  val loss 0.2783  train acc 0.9816  val acc 0.9242
# epoch 41  train loss 0.0718  val loss 0.2782  train acc 0.9842  val acc 0.9241
# epoch 42  train loss 0.0668  val loss 0.2874  train acc 0.9850  val acc 0.9201
# epoch 43  train loss 0.0641  val loss 0.2709  train acc 0.9872  val acc 0.9247
# epoch 44  train loss 0.0597  val loss 0.2775  train acc 0.9870  val acc 0.9241
# epoch 45  train loss 0.0575  val loss 0.2775  train acc 0.9876  val acc 0.9250
# epoch 46  train loss 0.0566  val loss 0.2825  train acc 0.9874  val acc 0.9221
# epoch 47  train loss 0.0588  val loss 0.2828  train acc 0.9874  val acc 0.9231
# epoch 48  train loss 0.0554  val loss 0.2821  train acc 0.9882  val acc 0.9246
# epoch 49  train loss 0.0517  val loss 0.2865  train acc 0.9900  val acc 0.9254
# epoch 50  train loss 0.0445  val loss 0.2827  train acc 0.9918  val acc 0.9250
# epoch 51  train loss 0.0465  val loss 0.2878  train acc 0.9922  val acc 0.9238
# epoch 52  train loss 0.0451  val loss 0.2918  train acc 0.9910  val acc 0.9244
# epoch 53  train loss 0.0384  val loss 0.2831  train acc 0.9936  val acc 0.9258
# epoch 54  train loss 0.0399  val loss 0.2880  train acc 0.9928  val acc 0.9269
# epoch 55  train loss 0.0344  val loss 0.2828  train acc 0.9946  val acc 0.9257
# epoch 56  train loss 0.0331  val loss 0.2943  train acc 0.9948  val acc 0.9228
# epoch 57  train loss 0.0302  val loss 0.2875  train acc 0.9968  val acc 0.9262
# epoch 58  train loss 0.0287  val loss 0.2919  train acc 0.9964  val acc 0.9272
# epoch 59  train loss 0.0371  val loss 0.2930  train acc 0.9932  val acc 0.9239
# epoch 60  train loss 0.0302  val loss 0.2931  train acc 0.9960  val acc 0.9254
# --- Thinned net 3 of 5 ---
# epoch  1  train loss 2.2542  val loss 2.1523  train acc 0.2120  val acc 0.4051
# epoch  2  train loss 1.9062  val loss 1.5086  train acc 0.4438  val acc 0.5530
# epoch  3  train loss 1.1310  val loss 0.8562  train acc 0.6824  val acc 0.7176
# epoch  4  train loss 0.7013  val loss 0.6129  train acc 0.7920  val acc 0.8228
# epoch  5  train loss 0.5362  val loss 0.5081  train acc 0.8502  val acc 0.8526
# epoch  6  train loss 0.4536  val loss 0.4586  train acc 0.8698  val acc 0.8681
# epoch  7  train loss 0.4083  val loss 0.4247  train acc 0.8854  val acc 0.8793
# epoch  8  train loss 0.3693  val loss 0.4015  train acc 0.8944  val acc 0.8849
# epoch  9  train loss 0.3413  val loss 0.3856  train acc 0.9034  val acc 0.8924
# epoch 10  train loss 0.3331  val loss 0.3766  train acc 0.9052  val acc 0.8915
# epoch 11  train loss 0.3078  val loss 0.3795  train acc 0.9146  val acc 0.8883
# epoch 12  train loss 0.3074  val loss 0.3635  train acc 0.9108  val acc 0.8949
# epoch 13  train loss 0.2793  val loss 0.3509  train acc 0.9222  val acc 0.9013
# epoch 14  train loss 0.2605  val loss 0.3332  train acc 0.9254  val acc 0.9027
# epoch 15  train loss 0.2487  val loss 0.3458  train acc 0.9280  val acc 0.8981
# epoch 16  train loss 0.2362  val loss 0.3319  train acc 0.9324  val acc 0.9026
# epoch 17  train loss 0.2296  val loss 0.3254  train acc 0.9342  val acc 0.9030
# epoch 18  train loss 0.2145  val loss 0.3242  train acc 0.9396  val acc 0.9063
# epoch 19  train loss 0.2106  val loss 0.3117  train acc 0.9380  val acc 0.9107
# epoch 20  train loss 0.1970  val loss 0.3210  train acc 0.9450  val acc 0.9063
# epoch 21  train loss 0.1836  val loss 0.2962  train acc 0.9488  val acc 0.9144
# epoch 22  train loss 0.1778  val loss 0.3022  train acc 0.9482  val acc 0.9120
# epoch 23  train loss 0.1732  val loss 0.3004  train acc 0.9510  val acc 0.9122
# epoch 24  train loss 0.1648  val loss 0.2876  train acc 0.9524  val acc 0.9172
# epoch 25  train loss 0.1519  val loss 0.2960  train acc 0.9582  val acc 0.9126
# epoch 26  train loss 0.1465  val loss 0.2874  train acc 0.9592  val acc 0.9187
# epoch 27  train loss 0.1359  val loss 0.2892  train acc 0.9638  val acc 0.9185
# epoch 28  train loss 0.1306  val loss 0.2839  train acc 0.9654  val acc 0.9195
# epoch 29  train loss 0.1344  val loss 0.2755  train acc 0.9620  val acc 0.9222
# epoch 30  train loss 0.1159  val loss 0.2777  train acc 0.9696  val acc 0.9222
# epoch 31  train loss 0.1115  val loss 0.2872  train acc 0.9706  val acc 0.9179
# epoch 32  train loss 0.1071  val loss 0.2809  train acc 0.9720  val acc 0.9203
# epoch 33  train loss 0.1007  val loss 0.2784  train acc 0.9744  val acc 0.9208
# epoch 34  train loss 0.0970  val loss 0.2792  train acc 0.9760  val acc 0.9215
# epoch 35  train loss 0.0897  val loss 0.2718  train acc 0.9788  val acc 0.9249
# epoch 36  train loss 0.0859  val loss 0.2734  train acc 0.9788  val acc 0.9240
# epoch 37  train loss 0.0815  val loss 0.2738  train acc 0.9798  val acc 0.9242
# epoch 38  train loss 0.0777  val loss 0.2728  train acc 0.9824  val acc 0.9255
# epoch 39  train loss 0.0725  val loss 0.2790  train acc 0.9844  val acc 0.9228
# epoch 40  train loss 0.0719  val loss 0.2772  train acc 0.9848  val acc 0.9218
# epoch 41  train loss 0.0661  val loss 0.2803  train acc 0.9848  val acc 0.9214
# epoch 42  train loss 0.0616  val loss 0.2840  train acc 0.9870  val acc 0.9228
# epoch 43  train loss 0.0611  val loss 0.2850  train acc 0.9866  val acc 0.9216
# epoch 44  train loss 0.0588  val loss 0.2827  train acc 0.9866  val acc 0.9238
# epoch 45  train loss 0.0542  val loss 0.2826  train acc 0.9884  val acc 0.9237
# epoch 46  train loss 0.0519  val loss 0.2886  train acc 0.9892  val acc 0.9243
# epoch 47  train loss 0.0601  val loss 0.2831  train acc 0.9856  val acc 0.9247
# epoch 48  train loss 0.0454  val loss 0.2796  train acc 0.9922  val acc 0.9269
# epoch 49  train loss 0.0423  val loss 0.2826  train acc 0.9930  val acc 0.9263
# epoch 50  train loss 0.0407  val loss 0.2801  train acc 0.9934  val acc 0.9273
# epoch 51  train loss 0.0374  val loss 0.2802  train acc 0.9942  val acc 0.9275
# epoch 52  train loss 0.0357  val loss 0.2850  train acc 0.9948  val acc 0.9262
# epoch 53  train loss 0.0335  val loss 0.2887  train acc 0.9954  val acc 0.9266
# epoch 54  train loss 0.0320  val loss 0.2893  train acc 0.9956  val acc 0.9259
# epoch 55  train loss 0.0324  val loss 0.2849  train acc 0.9956  val acc 0.9289
# epoch 56  train loss 0.0294  val loss 0.2859  train acc 0.9960  val acc 0.9277
# epoch 57  train loss 0.0268  val loss 0.2951  train acc 0.9968  val acc 0.9269
# epoch 58  train loss 0.0261  val loss 0.2931  train acc 0.9974  val acc 0.9261
# epoch 59  train loss 0.0248  val loss 0.2950  train acc 0.9976  val acc 0.9267
# epoch 60  train loss 0.0233  val loss 0.2953  train acc 0.9980  val acc 0.9267
# --- Thinned net 4 of 5 ---
# epoch  1  train loss 2.2832  val loss 2.2351  train acc 0.1506  val acc 0.2498
# epoch  2  train loss 2.0964  val loss 1.8366  train acc 0.4986  val acc 0.6100
# epoch  3  train loss 1.4259  val loss 0.9777  train acc 0.6858  val acc 0.7516
# epoch  4  train loss 0.7596  val loss 0.6288  train acc 0.7960  val acc 0.8200
# epoch  5  train loss 0.5553  val loss 0.5241  train acc 0.8396  val acc 0.8451
# epoch  6  train loss 0.4549  val loss 0.4520  train acc 0.8698  val acc 0.8690
# epoch  7  train loss 0.4094  val loss 0.4248  train acc 0.8834  val acc 0.8745
# epoch  8  train loss 0.3772  val loss 0.4148  train acc 0.8898  val acc 0.8758
# epoch  9  train loss 0.3673  val loss 0.3923  train acc 0.8874  val acc 0.8823
# epoch 10  train loss 0.3282  val loss 0.3848  train acc 0.9068  val acc 0.8874
# epoch 11  train loss 0.3109  val loss 0.3567  train acc 0.9136  val acc 0.8943
# epoch 12  train loss 0.2960  val loss 0.3565  train acc 0.9154  val acc 0.8978
# epoch 13  train loss 0.2832  val loss 0.3507  train acc 0.9160  val acc 0.8968
# epoch 14  train loss 0.2704  val loss 0.3422  train acc 0.9268  val acc 0.8974
# epoch 15  train loss 0.2570  val loss 0.3618  train acc 0.9280  val acc 0.8936
# epoch 16  train loss 0.2636  val loss 0.3576  train acc 0.9258  val acc 0.8953
# epoch 17  train loss 0.2418  val loss 0.3444  train acc 0.9352  val acc 0.9001
# epoch 18  train loss 0.2245  val loss 0.3281  train acc 0.9370  val acc 0.9083
# epoch 19  train loss 0.2209  val loss 0.3246  train acc 0.9388  val acc 0.9079
# epoch 20  train loss 0.2104  val loss 0.3231  train acc 0.9410  val acc 0.9097
# epoch 21  train loss 0.1977  val loss 0.3284  train acc 0.9468  val acc 0.9055
# epoch 22  train loss 0.1893  val loss 0.3170  train acc 0.9514  val acc 0.9108
# epoch 23  train loss 0.1850  val loss 0.3111  train acc 0.9502  val acc 0.9131
# epoch 24  train loss 0.1756  val loss 0.3239  train acc 0.9520  val acc 0.9068
# epoch 25  train loss 0.1718  val loss 0.2996  train acc 0.9546  val acc 0.9144
# epoch 26  train loss 0.1595  val loss 0.2980  train acc 0.9588  val acc 0.9160
# epoch 27  train loss 0.1580  val loss 0.3059  train acc 0.9574  val acc 0.9139
# epoch 28  train loss 0.1477  val loss 0.2905  train acc 0.9612  val acc 0.9189
# epoch 29  train loss 0.1457  val loss 0.2948  train acc 0.9624  val acc 0.9136
# epoch 30  train loss 0.1402  val loss 0.2930  train acc 0.9630  val acc 0.9160
# epoch 31  train loss 0.1312  val loss 0.2985  train acc 0.9656  val acc 0.9154
# epoch 32  train loss 0.1279  val loss 0.2950  train acc 0.9674  val acc 0.9158
# epoch 33  train loss 0.1291  val loss 0.3025  train acc 0.9632  val acc 0.9170
# epoch 34  train loss 0.1187  val loss 0.2980  train acc 0.9696  val acc 0.9149
# epoch 35  train loss 0.1496  val loss 0.2909  train acc 0.9566  val acc 0.9176
# epoch 36  train loss 0.1115  val loss 0.2980  train acc 0.9730  val acc 0.9168
# epoch 37  train loss 0.1040  val loss 0.2864  train acc 0.9734  val acc 0.9188
# epoch 38  train loss 0.0984  val loss 0.2923  train acc 0.9780  val acc 0.9200
# epoch 39  train loss 0.0943  val loss 0.2833  train acc 0.9766  val acc 0.9212
# epoch 40  train loss 0.0862  val loss 0.2850  train acc 0.9796  val acc 0.9195
# epoch 41  train loss 0.0843  val loss 0.2911  train acc 0.9808  val acc 0.9184
# epoch 42  train loss 0.0800  val loss 0.2907  train acc 0.9816  val acc 0.9193
# epoch 43  train loss 0.0775  val loss 0.2980  train acc 0.9820  val acc 0.9201
# epoch 44  train loss 0.0863  val loss 0.2947  train acc 0.9782  val acc 0.9202
# epoch 45  train loss 0.0864  val loss 0.2833  train acc 0.9746  val acc 0.9213
# epoch 46  train loss 0.0685  val loss 0.2863  train acc 0.9838  val acc 0.9221
# epoch 47  train loss 0.0622  val loss 0.2888  train acc 0.9864  val acc 0.9242
# epoch 48  train loss 0.0599  val loss 0.2908  train acc 0.9874  val acc 0.9212
# epoch 49  train loss 0.0557  val loss 0.2849  train acc 0.9878  val acc 0.9239
# epoch 50  train loss 0.0531  val loss 0.2960  train acc 0.9896  val acc 0.9216
# epoch 51  train loss 0.0791  val loss 0.2919  train acc 0.9788  val acc 0.9246
# epoch 52  train loss 0.0581  val loss 0.2940  train acc 0.9862  val acc 0.9240
# epoch 53  train loss 0.0493  val loss 0.2920  train acc 0.9900  val acc 0.9232
# epoch 54  train loss 0.0429  val loss 0.2855  train acc 0.9928  val acc 0.9258
# epoch 55  train loss 0.0523  val loss 0.3026  train acc 0.9888  val acc 0.9211
# epoch 56  train loss 0.0427  val loss 0.2921  train acc 0.9922  val acc 0.9242
# epoch 57  train loss 0.0371  val loss 0.2931  train acc 0.9940  val acc 0.9246
# epoch 58  train loss 0.0331  val loss 0.2927  train acc 0.9962  val acc 0.9254
# epoch 59  train loss 0.0313  val loss 0.2943  train acc 0.9962  val acc 0.9250
# epoch 60  train loss 0.0309  val loss 0.2978  train acc 0.9972  val acc 0.9237
# --- Thinned net 5 of 5 ---
# epoch  1  train loss 2.2732  val loss 2.2107  train acc 0.2268  val acc 0.4754
# epoch  2  train loss 2.0498  val loss 1.7716  train acc 0.5240  val acc 0.5766
# epoch  3  train loss 1.3441  val loss 0.9403  train acc 0.6840  val acc 0.7334
# epoch  4  train loss 0.7546  val loss 0.6497  train acc 0.7856  val acc 0.8027
# epoch  5  train loss 0.5556  val loss 0.5189  train acc 0.8418  val acc 0.8484
# epoch  6  train loss 0.4685  val loss 0.4640  train acc 0.8682  val acc 0.8673
# epoch  7  train loss 0.4114  val loss 0.4291  train acc 0.8868  val acc 0.8758
# epoch  8  train loss 0.3777  val loss 0.4271  train acc 0.8934  val acc 0.8730
# epoch  9  train loss 0.3582  val loss 0.4400  train acc 0.8978  val acc 0.8680
# epoch 10  train loss 0.3498  val loss 0.3921  train acc 0.8964  val acc 0.8871
# epoch 11  train loss 0.3192  val loss 0.3777  train acc 0.9080  val acc 0.8916
# epoch 12  train loss 0.3068  val loss 0.3659  train acc 0.9122  val acc 0.8953
# epoch 13  train loss 0.2894  val loss 0.3554  train acc 0.9186  val acc 0.8983
# epoch 14  train loss 0.2724  val loss 0.3557  train acc 0.9242  val acc 0.8962
# epoch 15  train loss 0.2603  val loss 0.3455  train acc 0.9260  val acc 0.9021
# epoch 16  train loss 0.2499  val loss 0.3435  train acc 0.9322  val acc 0.9014
# epoch 17  train loss 0.2377  val loss 0.3423  train acc 0.9332  val acc 0.9025
# epoch 18  train loss 0.2340  val loss 0.3460  train acc 0.9348  val acc 0.8988
# epoch 19  train loss 0.2292  val loss 0.3263  train acc 0.9374  val acc 0.9070
# epoch 20  train loss 0.2071  val loss 0.3308  train acc 0.9432  val acc 0.9041
# epoch 21  train loss 0.2008  val loss 0.3112  train acc 0.9470  val acc 0.9108
# epoch 22  train loss 0.1900  val loss 0.3085  train acc 0.9494  val acc 0.9137
# epoch 23  train loss 0.1853  val loss 0.3088  train acc 0.9478  val acc 0.9126
# epoch 24  train loss 0.1729  val loss 0.3029  train acc 0.9536  val acc 0.9156
# epoch 25  train loss 0.1727  val loss 0.3097  train acc 0.9520  val acc 0.9106
# epoch 26  train loss 0.1632  val loss 0.3026  train acc 0.9572  val acc 0.9143
# epoch 27  train loss 0.1669  val loss 0.3127  train acc 0.9522  val acc 0.9116
# epoch 28  train loss 0.1501  val loss 0.2963  train acc 0.9576  val acc 0.9154
# epoch 29  train loss 0.1394  val loss 0.2900  train acc 0.9620  val acc 0.9183
# epoch 30  train loss 0.1398  val loss 0.2954  train acc 0.9624  val acc 0.9172
# epoch 31  train loss 0.1479  val loss 0.2845  train acc 0.9554  val acc 0.9189
# epoch 32  train loss 0.1211  val loss 0.2965  train acc 0.9702  val acc 0.9151
# epoch 33  train loss 0.1147  val loss 0.2849  train acc 0.9714  val acc 0.9203
# epoch 34  train loss 0.1088  val loss 0.2979  train acc 0.9720  val acc 0.9180
# epoch 35  train loss 0.1030  val loss 0.2829  train acc 0.9726  val acc 0.9233
# epoch 36  train loss 0.1003  val loss 0.2797  train acc 0.9756  val acc 0.9238
# epoch 37  train loss 0.0940  val loss 0.2840  train acc 0.9774  val acc 0.9226
# epoch 38  train loss 0.0883  val loss 0.2864  train acc 0.9788  val acc 0.9219
# epoch 39  train loss 0.0841  val loss 0.2917  train acc 0.9794  val acc 0.9186
# epoch 40  train loss 0.0802  val loss 0.2901  train acc 0.9820  val acc 0.9207
# epoch 41  train loss 0.0763  val loss 0.2853  train acc 0.9836  val acc 0.9230
# epoch 42  train loss 0.0745  val loss 0.2869  train acc 0.9838  val acc 0.9231
# epoch 43  train loss 0.0692  val loss 0.2862  train acc 0.9846  val acc 0.9228
# epoch 44  train loss 0.0676  val loss 0.2943  train acc 0.9826  val acc 0.9231
# epoch 45  train loss 0.0626  val loss 0.2886  train acc 0.9872  val acc 0.9235
# epoch 46  train loss 0.0592  val loss 0.2987  train acc 0.9882  val acc 0.9230
# epoch 47  train loss 0.0564  val loss 0.2941  train acc 0.9884  val acc 0.9240
# epoch 48  train loss 0.0525  val loss 0.2901  train acc 0.9904  val acc 0.9256
# epoch 49  train loss 0.0510  val loss 0.2912  train acc 0.9892  val acc 0.9256
# epoch 50  train loss 0.0486  val loss 0.3065  train acc 0.9916  val acc 0.9204
# epoch 51  train loss 0.0696  val loss 0.3114  train acc 0.9828  val acc 0.9183
# epoch 52  train loss 0.0439  val loss 0.2988  train acc 0.9922  val acc 0.9253
# epoch 53  train loss 0.0401  val loss 0.2954  train acc 0.9932  val acc 0.9258
# epoch 54  train loss 0.0363  val loss 0.3126  train acc 0.9956  val acc 0.9211
# epoch 55  train loss 0.0565  val loss 0.2959  train acc 0.9886  val acc 0.9251
# epoch 56  train loss 0.0360  val loss 0.2975  train acc 0.9942  val acc 0.9249
# epoch 57  train loss 0.0320  val loss 0.2992  train acc 0.9958  val acc 0.9265
# epoch 58  train loss 0.0331  val loss 0.2987  train acc 0.9958  val acc 0.9279
# epoch 59  train loss 0.0283  val loss 0.3009  train acc 0.9968  val acc 0.9276
# epoch 60  train loss 0.0284  val loss 0.3072  train acc 0.9972  val acc 0.9263
# Trained 5 thinned subnetworks.

# %% [markdown]
# ### 2.3 Ensemble prediction
#
# At test time, each thinned net returns logits; we apply softmax, average the resulting probability vectors across the $K$ networks, then take the argmax. This is the standard ensemble rule.

# %%
@torch.no_grad()
def ensemble_predict(models, loader):
    """Return overall test accuracy of the softmax-averaged ensemble."""
    for m in models:
        m.eval()
    total_correct, total_count = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        probs = torch.zeros(x.size(0), 10, device=device)
        for m in models:
            probs += torch.softmax(m(x), dim=1)
        probs /= len(models)
        preds = probs.argmax(dim=1)
        total_correct += (preds == y).sum().item()
        total_count   += x.size(0)
    return total_correct / total_count

test_acc_ensemble = ensemble_predict(thinned_models, test_loader)
print(f'Ensemble test accuracy (K = {K} thinned nets): {test_acc_ensemble:.4f}')
# Out:
# Ensemble test accuracy (K = 5 thinned nets): 0.9351

# %% [markdown]
# ### 2.4 Side-by-side comparison
#
# Three test accuracies: the unregularised baseline, the single dropout network, and the ensemble of $K$ thinned subnetworks.

# %%
thinned_individual_accs = []
for k, m in enumerate(thinned_models):
    _, acc = evaluate(m, test_loader, criterion)
    thinned_individual_accs.append(acc)

print('Test accuracies:')
print(f'  baseline (no regularisation):   {test_acc_baseline:.4f}')
print(f'  one net with dropout(0.5):      {test_acc_dropout:.4f}')
print(f'  best individual thinned net:    {max(thinned_individual_accs):.4f}')
print(f'  mean individual thinned net:    {np.mean(thinned_individual_accs):.4f}')
print(f'  ensemble of {K} thinned nets:    {test_acc_ensemble:.4f}')

fig, ax = plt.subplots(figsize=(7, 4))
labels = ['baseline', 'dropout', 'thinned\n(best)', 'thinned\n(mean)', f'ensemble\n(K={K})']
values = [test_acc_baseline, test_acc_dropout, max(thinned_individual_accs),
          float(np.mean(thinned_individual_accs)), test_acc_ensemble]
bars = ax.bar(labels, values, color=['gray', 'C0', 'C2', 'C2', 'C3'])
for b, v in zip(bars, values):
    ax.text(b.get_x() + b.get_width() / 2, v + 0.001, f'{v:.4f}',
            ha='center', va='bottom', fontsize=9)
ax.set_ylim(min(values) - 0.01, max(values) + 0.01)
ax.set_ylabel('test accuracy')
ax.set_title('Dropout vs ensemble of thinned networks')
plt.tight_layout(); plt.show()
# Out:
# Test accuracies:
#   baseline (no regularisation):   0.9328
#   one net with dropout(0.5):      0.9360
#   best individual thinned net:    0.9328
#   mean individual thinned net:    0.9286
#   ensemble of 5 thinned nets:    0.9351

# %% [markdown]
# ### 2.5 What did we just see?
#
# Read off the bar chart. Three things to notice.
#
# * **The baseline overfits.** Its training accuracy reached close to $100\%$ but its test accuracy is significantly lower; this is the gap that regularisation is meant to close.
# * **The single dropout net closes that gap.** Trained on the same 5,000 samples with the same architecture, but with `nn.Dropout(0.5)` between the hidden layers, it generalises better than the baseline. The randomness during training prevents the net from memorising any single training pattern too aggressively.
# * **The ensemble of $K$ thinned subnetworks closes the gap by another route, and ends up at a similar test accuracy to the dropout net.** Each thinned net individually has lower capacity and underfits a bit; averaging $K$ of them cancels the idiosyncratic errors of each one.
#
# That last point is the empirical content of the dropout-as-ensemble claim. Dropout buys you the variance-reduction benefit of ensembling *without* having to train, store, and run $K$ separate networks. One parameter vector implicitly carries the averaged behaviour of an exponentially large family of thinned subnetworks; at test time, a single forward pass through the full network is approximately the ensemble's averaged prediction.

# %% [markdown]
# > ### <font color="#1b5e20">2.6 Tasks</font>
# >
# > Two tasks. The second is the most interesting thing in the notebook; do not skip it.
# >
# > <font color="#1b5e20">**Task 2.6.1: change the dropout rate.**</font> Re-run section 2.1 with $p = 0.2$ and then $p = 0.8$. Plot the validation curves alongside the original $p = 0.5$ result. Does a higher dropout rate always help? Why does $p = 0.8$ hurt? Connect to the Week 2 §6 view that dropout effectively reduces the capacity used per forward pass by a factor of $1 - p$.
# >
# > <font color="#1b5e20">**Task 2.6.2: Monte Carlo dropout at test time.**</font> When we evaluated the dropout net in section 2.1 we called `model.eval()`, which switches `nn.Dropout` into pass-through mode and gives us one deterministic forward pass. Try the *opposite*: put the trained `model_dropout` into train mode (`model_dropout.train()`), then push the test set through it $T = 20$ times, each time with a fresh random dropout mask, and average the $T$ softmax outputs before taking the argmax. (Hint: this is essentially `ensemble_predict` from section 2.3 but with *one* trained network instead of $K$ separate ones; use the `@torch.no_grad()` decorator to skip gradient tracking, but do *not* call `model.eval()`.) You should now have three test accuracies for comparison: the standard dropout-off test pass from section 2.1, the $K$-thinned-net ensemble from section 2.4, and this new Monte Carlo dropout number. All three should land within a fraction of a percent of each other. This is the dropout-as-ensemble equivalence made empirical from a fresh angle: the trained dropout network already carries the ensemble *inside* it, and you can recover the averaged prediction by sampling subnetworks at test time, no separate networks required. (For the curious: this trick is called *Monte Carlo dropout*; Gal and Ghahramani (2016) use it to get cheap predictive uncertainty estimates from deep networks.)

# %%
# Task 2.6.2: Monte Carlo dropout at test time.
#
# Steps to fill in:
#   1. Put model_dropout into train mode so nn.Dropout keeps sampling masks
#      at test time. (Do NOT call model.eval() afterwards.)
#   2. Define mc_dropout_predict(model, loader, T) decorated with @torch.no_grad():
#      for each batch, run T forward passes through `model`, accumulate the
#      softmax outputs (T tensors of shape (batch, 10)), divide by T, take argmax.
#      Tally correct vs total exactly as in ensemble_predict (section 2.3).
#   3. Run mc_dropout_predict(model_dropout, test_loader, T=20) to get acc_mc.
#   4. Print acc_mc alongside test_acc_dropout (the standard eval-mode number
#      from section 2.1) and test_acc_ensemble (the K-thinned-net ensemble from
#      section 2.4) so all three can be compared directly.

# TODO: your code here.
pass
